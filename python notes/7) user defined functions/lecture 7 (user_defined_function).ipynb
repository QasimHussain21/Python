# %% [markdown]
# # Lecture no 7 (User_Defined_Functions):-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # creating and calling a function

# %%
def my_function():
    print("Hello i am qasim hussain")

# %%
my_function()
# Out:
# Hello i am qasim hussain

# %%
def details_bill():
    print("the last date of the bill payment is on next week sunday")
    print("after deadline, you need to pay rs 1000 as a fine")
    print("pay your bill soon")

# %%
for i in range(1):
    a = input("enter your name")
    b = int(input("enter the unit as electricity you have consumed"))
    bill = b*10
    print("total amount of bill you need to pay is", bill)
    details_bill()
# Out:
# enter your name qasim hussain
# enter the unit as electricity you have consumed 2000
# total amount of bill you need to pay is 20000
# the last date of the bill payment is on next week sunday
# after deadline, you need to pay rs 1000 as a fine
# pay your bill soon

# %% [markdown]
# # Arguments

# %% [markdown]
# # create a function, which checks the number is even or odd

# %%
def check_even_odd(number):
    if number%2==0:
       print("the number is even")
    else:
        print("the number is odd")

# %%
check_even_odd(24)
# Out:
# the number is even

# %%
check_even_odd(23)
# Out:
# the number is odd

# %% [markdown]
# # 2 Arguments

# %%
def my_name(fname, lname):
    print(fname + "  " + lname)

# %%
my_name("qasim", "hussain")
# Out:
# qasim  hussain

# %% [raw]
# Write a user defined function to process the exam scores and calculate the following statistics:
#
# The average exam score.
# The highest exam score.
# The lowest exam score.
# The number of students who passed the exam (assuming a passing score is 80 or above)
# The number of students who failed the exam.
#
# exam_scores = [85,92,78,88,95,87,91]

# %%
def calculate_exam_statistics(exam_scores):
    num_students = len(exam_scores)
    average_score = sum(exam_scores) / num_students
    highest_score = max(exam_scores)
    lowest_score = min(exam_scores)

    num_passed = 0
    for score in exam_scores:
        if score >= 80:   # pass mark = 80
            num_passed = num_passed + 1

    num_failed = num_students - num_passed

    return average_score, highest_score, lowest_score, num_passed, num_failed

# %%
# Data
exam_scores = [85, 92, 78, 90, 95, 82, 79, 87, 91]

# Call function
average_score, highest_score, lowest_score, num_passed, num_failed = calculate_exam_statistics(exam_scores)

# Print results
print("The average score is", average_score)
print("The highest score is", highest_score)
print("The lowest score is", lowest_score)
print("The number of students passed is", num_passed)
print("The number of students failed is", num_failed)
# Out:
# The average score is 86.55555555555556
# The highest score is 95
# The lowest score is 78
# The number of students passed is 7
# The number of students failed is 2

# %% [markdown]
# # Practice Questions

# %% [markdown]
# # Making the result of a student:-

# %%
def contact():
    print("Contact details of the school")
    print("Karachi public school")
    print("Karachi")
    print("0300157715")
    print("hps.contact&gmail.com")

# %%
for i in range(1):
    a = input("Name of the student")
    b= int(input("enter the marks of  math"))
    c= int(input("enter the marks of  social"))
    d= int(input("enter the marks of  science"))
    print()
    contact()
# Out:
# Name of the student Qasim Hussain
# enter the marks of  math 10
# enter the marks of  social 23
# enter the marks of  science 33
# Contact details of the school
# Karachi public school
# Karachi
# 0300157715
# hps.contact&gmail.com

# %% [raw]
# # write a program to calculate the electricity bill
#
# if 500 unit used _ pay Rs 5 for each unit
# if 700 unit used _ pay Rs 10 for each unit
# if 1000 unit used _ pay Rs 15 for each unit
# if more than 1000 unit used _ pay 20 Rs for each unit

# %%
def electricity_bill(n):
    if n<=500:
        print("your bill is Rs", n*5)
    elif n>500 and n<=700:
        print("your bill is Rs", n*10)
    elif n>700 and n<=1000:
        print("your bill is Rs", n*15)
    elif n>1000:
        print("your bill is Rs", n*20)

# %%
def instructions():
    print("last date of paying the bill is 24 Feb")
    print("after 24 Feb you need to pay 1000 Rs as a fine")
    print("electricity office new karachi")

# %%
for i in range(1):
    a = input("Enter the name of a customer")
    n = int(input("Enter the unit of electricity you have used"))
    electricity_bill(n)
    print()
    instructions()
# Out:
# Enter the name of a customer Qasim Hussain
# Enter the unit of electricity you have used 23
# your bill is Rs 115
#
# last date of paying the bill is 24 Feb
# after 24 Feb you need to pay 1000 Rs as a fine
# electricity office new karachi

# %% [markdown]
# ![image.png](attachment:88202476-7178-4803-905f-6c405f0656ec.png)

# %% [markdown]
# ![image.png](attachment:20732ca5-3a05-4d5d-9fc2-f08e036ddccd.png)

# %% [markdown]
# ![image.png](attachment:4c9a5c1b-e0e4-4bbb-8ebf-cc8458eab4e5.png)

# %% [markdown]
# ![image.png](attachment:ea22baef-9ef8-41b0-89c1-6a6bd5fec1f0.png)

# %% [markdown]
# ![image.png](attachment:82387817-4369-4742-8318-dc559f01802f.png)

# %% [markdown]
# ![image.png](attachment:477543eb-d02e-4ad5-b4bc-12864d8fdb84.png)

# %% [markdown]
# ![image.png](attachment:9b740768-6680-4740-9f5c-dca03d2d643e.png)
