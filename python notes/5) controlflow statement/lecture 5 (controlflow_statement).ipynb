# %% [markdown]
# # Lecture no 5:- (Controlflow_Statement):-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:93f18f46-07fa-4035-a6f0-a33b909d78cd.png)

# %% [markdown]
# ![image.png](attachment:802421ee-cb42-426c-8337-45ef74b09d21.png)

# %% [markdown]
# ![image.png](attachment:376a853f-6d2d-4f0a-95c6-860c3a60fd16.png)

# %% [markdown]
# ![image.png](attachment:1cf3f3ca-1094-4881-9f0e-e832f3455ece.png)

# %% [markdown]
# # if statement execution

# %%
i = 20
if i<=10:
    print("20 is greater than 10")
print("condition is false")
# Out:
# condition is false

# %% [markdown]
# ![image.png](attachment:b1054c5f-69da-4177-b0c6-e6dffb77f514.png)

# %%
temp = float(input("Enter the temperature:"))

if temp<15:
    print("temperature is not convinient")

if 24<temp<28:
    print("temperature is convenient")
# Out:
# Enter the temperature: 12
# temperature is not convinient

# %% [markdown]
# # if else

# %% [markdown]
# ![image.png](attachment:bcd51f9a-8b7b-4c91-9fd4-89705dba2575.png)

# %%
age = int(input("Enter your age:"))

if age>=18:
    print("you are eligible for vote:")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age: 18
# you are eligible for vote:

# %% [markdown]
# ![image.png](attachment:81df5786-5c4c-4cfd-8bce-7debdcbc0207.png)

# %%
base_salary = float(input("Enter your base salary"))
years_of_service = int(input("Enter your years of service"))

if years_of_service >5:
    total_salary = base_salary + (0.08*base_salary)-(0.12*base_salary)
    print("you will get net salary", total_salary)

else:
    net_salary = base_salary - (0.12*base_salary)
    print("your net salary is:", net_salary)
# Out:
# Enter your base salary 200000
# Enter your years of service 6
# you will get net salary 192000.0

# %% [markdown]
# # email and password if condition program

# %%
email = input("Enter your email")
password = input("Enter your password")

if email == "qasim.hussain2410@gmail.com" and password == "12345678910":
    print("Welcome to python world")
else:
    print("No email and password found")
# Out:
# Enter your email 12345678910
# Enter your password 77
# No email and password found

# %% [markdown]
# # if elif else

# %% [markdown]
# ![image.png](attachment:d4c0b2cf-3e97-464a-9767-b62cb3634544.png)

# %%
a = input("enter the city")

if a== "Pakistan":
    print("The famous monument is Minar-e-Pakistan")
    
elif a== "Islamabad":
    print("The famous monument of islamabad is Faisal-Masjid")
else:
    print("no record found")
# Out:
# enter the city Quetta
# no record found

# %% [markdown]
# # Practice Questions

# %% [markdown]
# # If Condition:-

# %% [raw]
# Write a program to calculate the percentage of a student in the subjects maths science social eng and urdu:-

# %%
x = input("Enter the name of a student")
a = int(input("Enter the name of a english"))
b = int(input("Enter the marks of  urdu"))
c = int(input("Enter the marks of  maths"))
d = int(input("Enter the marks of  science"))
e = int(input("Enter the marks of  social"))
n =((a+b+c+d+e)/500)*100
print("the percent scored by student is",n)
# Out:
# Enter the name of a student Qasim Hussain
# Enter the name of a english 12
# Enter the marks of  urdu 22
# Enter the marks of  maths 34
# Enter the marks of  science 56
# Enter the marks of  social 78
# the percent scored by student is 40.400000000000006

# %% [raw]
# If percentage is above 90 - assign A grade
# if percentage is above 75 - assign B grade
# if percentage is above 65 - assign C grade

# %%
a = int(input("enter the percentage scored by a student"))

if a>=90:
    print("A grade")
if a>=75 and a<90:
    print("B grade")
if a>=65 and a<75:
    print("C grade") 
if a<=60:
    print("F grade")
# Out:
# enter the percentage scored by a student 245
# A grade

# %% [markdown]
# # If else statement:-

# %% [raw]
# Write a program to display hello if number entered by a user is a multiple of 5 else print py:-

# %%
a = int(input("enter the number"))
if a%5==0:
    print("hello")
else:
     print("bye")
# Out:
# enter the number 22
# bye

# %%
a = int(input("enter the number"))
if a>0:
    print("positive number")
else:
    print("negative number")
# Out:
# enter the number 12
# positive number

# %% [markdown]
# # if-else examples
# # 1. Find the min of 3 given numbers

# %%
# min of 3 number

a = int(input('first num'))
b = int(input('second num' ))
c = int(input('third num'))

if a<b and a<c:
    print('smallest is' ,a)
elif b<c:
    print('smallest is',b)
else:
    print('smallest is',c)
# Out:
# first num 1
# second num 1
# third num 1
# smallest is 1

# %% [markdown]
# # 2. Menu Driven Program   (Calculator)

# %%
a = int(input("Enter your first number: "))
b = int(input("Enter your second number: "))
op = input("Enter operator (+, -, *, /): ")

if op == "+":
    print(a + b)
elif op == "-":
    print(a - b)
elif op == "*":
    print(a * b)
elif op == "/":
    if b != 0:           # nested if for zero check
        print(a / b)
    else:
        print("Cannot divide by zero")
else:
    print("Invalid operator")
# Out:
# Enter your first number:  0
# Enter your second number:  0
# Enter operator (+, -, *, /):  /
# Cannot divide by zero

# %% [markdown]
# # If - elif - else:-

# %% [markdown]
# # Accept the city and print its monument
# Delhi - Red fort
# Agra - Taj mahal
# Jairpur - Jalmahal
# Orissa - Konak Temple
# Hyderabad - Charminar
# Other - Record not found

# %%
city = input("enter the city")
if city =="Delhi":
    print("The monument in delhi is Redfort")
elif city=="Agra":
    print("The monument in Agra is Tajmahal")
elif city=="Jairpur":
    print("The monument in Jairpur is Jalmahal")
elif city=="Orissa":
    print("The monument in Orissa is Konak Temple")
elif city=="Hyderabad":
    print("The monument in hyderabad is Charminar")
else:
    print("no record found")
# Out:
# enter the city kd
# no record found

# %% [markdown]
# # Login and password program using if, elif, else, nested if-else :

# %%
email = input('enter email')
password = input('enter password')

if email == 'qasim.hussain2410@gmail.com' and password == '1234':
    print('Welcome')
elif email == 'qasim.hussain2410@gmail.com' and password != '1234':
# tell the user
    print('Incorrect password')
    password = input('enter password again')
    if password == '1234':
        print('Welcome, finally!')
    else:
        print('beta tumse na ho paayega!')
else:
    print('Not correct')
# Out:
# enter email qasim.hussain2410@gmail.com
# enter password 1
# Incorrect password
# enter password again 1234
# Welcome, finally!

# %%
email = input('enter email')
password = input('enter password')

if email == 'nitish.campusx@gmail.com' and password == '1234':
    print('Welcome')

elif email == 'nitish.campusx@gmail.com' and password != '1234':
    print('Incorrect password')
    password = input('enter password again')
    if password == '1234':
        print('Welcome, finally!')
    else:
        print('beta tumse na ho paayega!')
else:
    print('Not correct')
# Out:
# enter email qasim.hussain2410@gmail.com
# enter password 1
# Not correct

# %% [markdown]
# ![image.png](attachment:f09eb4f2-a8f2-44ee-b1a4-508de2667528.png)

# %% [markdown]
# ![image.png](attachment:1ae10c57-e63b-4a3b-83f2-baa616238a85.png)

# %% [markdown]
# ![image.png](attachment:33f5eeae-48b7-4303-ad2c-0f27a5550ccd.png)

# %% [markdown]
# ![image.png](attachment:b62c69b8-cbca-44ed-bb5d-1e0a824837be.png)

# %% [markdown]
# ![image.png](attachment:e3514ec5-a395-4332-8a09-af4df907940f.png)

# %% [markdown]
# # Behind the scene data science working
# ![image.png](attachment:66f38bff-3403-42c8-bc1f-3480f3047919.png)

# %% [markdown]
# ![image.png](attachment:d2aa9d95-1089-4a70-8fdb-fb6d31c45013.png)
