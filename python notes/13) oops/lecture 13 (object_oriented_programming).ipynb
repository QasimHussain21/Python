# %% [markdown]
# ![image.png](attachment:3c022fec-4e84-441f-9bd6-94352cd57f4b.png)

# %% [markdown]
# ![image.png](attachment:2fc0ee07-160f-4147-b860-8467fd41add1.png)

# %% [markdown]
# ![image.png](attachment:6e255741-79f1-4e63-8a97-ec111b33d353.png)

# %% [markdown]
# ![image.png](attachment:9cfb6986-b460-4266-be00-81bfa40ad1bd.png)

# %% [markdown]
# ![image.png](attachment:f10db83b-1588-467a-945c-9c2f26485e41.png)

# %% [markdown]
# ![image.png](attachment:6954870c-8256-4d17-89f0-2f489848730c.png)
